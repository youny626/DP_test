# %%
import pandas as pd

# %%
df1 = pd.read_csv("prolific_participant.csv")
# df1 = df1[df1["Status"] == "APPROVED"]
df1
# Out:
#                 Submission id            Participant id    Status  \
# 0    6376a4f922d513e38384c6da  60db7b5d510bd0a73fbbf46f  APPROVED
# 1    6376a5175ce2b30edb7a924e  5f80b75d46ee0012d2634d26  APPROVED
# 2    6376a55d090b0e8a3f8b31b0  60c7375cba154e330acc1f70  APPROVED
# 3    6376a574f58366a9b6c82ef8  613ad9f6446b3062b94e793c  APPROVED
# 4    6376a59376cbb0ae4a84c6ca  5f80a6f92dac9e105a84b405  APPROVED
# ..                        ...                       ...       ...
# 104  6376ad73faa6efeded1aa83e  5fd8a13aaf5bd723a0e0e3fa  APPROVED
# 105  6376ad7bb10593c1347ae375  60f8a5971d6b8523d04a321f  APPROVED
# 106  6376adb90f4d9a1e0c2a547f  6026bdfaf5361f3d0273bb9c  APPROVED
# 107  6376b5ed944076019fdc3e0a  5f97e6601f6d0e016087fc91  APPROVED
# 108  6376bcf540aadc26397ae362  5c573e54e9813700018acc31  APPROVED
#
#                       Started at                 Completed at  \
# 0    2022-11-17T21:17:54.508000Z  2022-11-17T21:19:47.740000Z
# ...

# %%
df2 = pd.read_csv("prolific_participant_new.csv")
# df2 = df2[df2["Status"] == "AWAITING REVIEW"]
df2
# Out:
#                 Submission id            Participant id           Status  \
# 0    6378050f90eb1599ab8940b8  5a71a1bb6fc3c60001f96797         RETURNED
# 1    6378059a4a9e1f07bbc82ef8  6154ae87f8e46e4407e55b98  AWAITING REVIEW
# 2    637805e488fa7a31958b31c9  5eff482a2e80084a8584b4f7  AWAITING REVIEW
# 3    63780604d5cb0a3eaf00248d  613a9da3c77e45388ba8a4c6  AWAITING REVIEW
# 4    6378062510b9485c2daf6103  60e62d6dd5c543a69e1767d5  AWAITING REVIEW
# ..                        ...                       ...              ...
# 106  63781259e4a318a439dc3dab  60a3cb60b3e2bdb82a865197  AWAITING REVIEW
# 107  6378126e8d0a1884e47a924b  5f0d9292ab8b8f0008f195dd  AWAITING REVIEW
# 108  6378141bec26dcc35872e6da  6092e666d6eecc26f1d89b87  AWAITING REVIEW
# 109  637814d73f0b4bf93177d0cb  60ff16c186d2024641575b61  AWAITING REVIEW
# 110  6378158a5fec01a749423b36  6154b3a7e4bc93e1ce93c6bc  AWAITING REVIEW
#
#                       Started at                 Completed at  Reviewed at  \
# ...

# %%
len(set(df1["Participant id"].to_list()).intersection(set(df2["Participant id"].to_list())))
# Out:
# 35

# %%
df = df2[df2['Participant id'].isin(set(df1["Participant id"].to_list()).intersection(set(df2["Participant id"].to_list())))]
# Out:
#                Submission id            Participant id           Status  \
# 5   637806479a21da986484c71a  608c2e566d92c2aa3543e2d2  AWAITING REVIEW
# 8   637806a20494a6bca47a9242  5e638770b45c641082fd309f  AWAITING REVIEW
# 16  637807bf7bb783dabb44c072  61181576fb9a7d8d0639e8e8  AWAITING REVIEW
# 24  637807fbd69479af5dc82efd  613fb424ed692f54b4ff7bff  AWAITING REVIEW
# 26  637808051b49d811b40f5797  610bb9c0c502bc7d0b4650f6  AWAITING REVIEW
# 27  6378080f92f59d4bbf0f57c1  60185218bc28d50a56653c58  AWAITING REVIEW
# 28  63780812d0d3361ff6491598  5d811e6ab395350018786d78  AWAITING REVIEW
# 33  6378089ccdfd4223c47a9268  5f80a6f92dac9e105a84b405  AWAITING REVIEW
# 35  637808cb152dc96d86fdfc87  60f48efecd0938da7c2f5dbc  AWAITING REVIEW
# 36  637808e5ba23d9cb032a5423  60c101e4634ffb1aa797b924  AWAITING REVIEW
# 42  6378097d929f37f0b59d4f8e  614fb54a636d939d60da5818  AWAITING REVIEW
# 45  637809bf9ed85c934ed2470b  572b96ba3ab9df000dbb4461  AWAITING REVIEW
# ...
