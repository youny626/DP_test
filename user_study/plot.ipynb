# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DP_study_result_new_nov_18.csv")
df.columns = ["control1", "control2", "test1", "test2", "test_follow_up", "q3", "q4", "initial_q"]
df
# Out:
#     control1  control2  test1  test2 test_follow_up  \
# 0        2.5       3.0    NaN    NaN            NaN
# 1        NaN       NaN    1.0    1.0            Yes
# 2        1.0       1.5    NaN    NaN            NaN
# 3        3.5       3.5    NaN    NaN            NaN
# 4        NaN       NaN    1.5    2.0            Yes
# 5        NaN       NaN    1.5    2.0            Yes
# 6        3.5       3.5    NaN    NaN            NaN
# 7        3.5       3.5    NaN    NaN            NaN
# 8        NaN       NaN    1.0    1.5            Yes
# 9        NaN       NaN    2.0    2.0            Yes
# 10       2.0       3.0    NaN    NaN            NaN
# 11       1.5       2.0    NaN    NaN            NaN
# 12       4.0       4.0    NaN    NaN            NaN
# 13       NaN       NaN    2.5    2.5            Yes
# 14       NaN       NaN    1.5    2.0            Yes
# 15       NaN       NaN    2.0    1.5            Yes
# 16       2.0       1.5    NaN    NaN            NaN
# 17       4.0       3.5    NaN    NaN            NaN
# 18       2.0       3.0    NaN    NaN            NaN
# 19       2.0       4.0    NaN    NaN            NaN
# 20       NaN       NaN    2.0    1.5            Yes
# 21       2.5       1.5    NaN    NaN            NaN
# 22       NaN       NaN    1.5    2.0            Yes
# 23       NaN       NaN    2.0    1.5            Yes
# 24       0.5       0.5    NaN    NaN            NaN
# 25       NaN       NaN    1.5    2.0            Yes
# 26       4.5       4.0    NaN    NaN            NaN
# 27       NaN       NaN    3.0    2.0            Yes
# 28       NaN       NaN    2.0    1.5            Yes
# 29       NaN       NaN    2.5    3.0            Yes
# 30       NaN       NaN    1.5    2.0            Yes
# 31       2.0       4.5    NaN    NaN            NaN
# 32       4.5       4.0    NaN    NaN            NaN
# 33       3.0       3.5    NaN    NaN            NaN
# 34       NaN       NaN    2.0    2.0            Yes
# 35       3.5       4.0    NaN    NaN            NaN
# 36       NaN       NaN    2.5    3.0            Yes
# 37       NaN       NaN    1.5    2.0            Yes
# 38       4.0       5.0    NaN    NaN            NaN
# 39       NaN       NaN    1.5    4.0            Yes
# 40       1.5       2.5    NaN    NaN            NaN
# 41       3.0       2.5    NaN    NaN            NaN
# 42       NaN       NaN    2.0    1.5            Yes
# 43       2.0       4.0    NaN    NaN            NaN
# 44       3.5       5.0    NaN    NaN            NaN
# 45       NaN       NaN    2.0    2.0            Yes
# 46       2.0       2.0    NaN    NaN            NaN
# 47       NaN       NaN    2.0    3.0            Yes
# 48       NaN       NaN    3.5    3.5            Yes
# 49       2.5       5.0    NaN    NaN            NaN
# 50       2.5       4.0    NaN    NaN            NaN
# 51       NaN       NaN    3.5    3.0            Yes
# 52       2.0       4.5    NaN    NaN            NaN
# 53       NaN       NaN    2.0    2.0            Yes
# 54       NaN       NaN    2.0    2.0            Yes
# 55       3.5       3.5    NaN    NaN            NaN
#
#                                                    q3  \
# 0   I prefer knowing only the prediction accuracy ...
# 1   I prefer knowing the prediction accuracy on bo...
# 2   I prefer knowing the prediction accuracy on bo...
# 3   I prefer knowing the prediction accuracy on bo...
# 4   I prefer knowing only the prediction accuracy ...
# 5   I prefer knowing only the prediction accuracy ...
# 6   I prefer knowing the prediction accuracy on bo...
# 7   I prefer knowing the prediction accuracy on bo...
# 8   I prefer knowing the prediction accuracy on bo...
# 9   I prefer knowing the prediction accuracy on bo...
# 10  I prefer knowing only the prediction accuracy ...
# 11  I prefer knowing only the prediction accuracy ...
# 12  I prefer knowing the prediction accuracy on bo...
# 13  I prefer knowing the prediction accuracy on bo...
# 14  I prefer knowing the prediction accuracy on bo...
# 15  I prefer knowing the prediction accuracy on bo...
# 16  I prefer knowing the prediction accuracy on bo...
# 17  I prefer knowing the prediction accuracy on bo...
# 18  I prefer knowing the prediction accuracy on bo...
# 19  I prefer knowing the prediction accuracy on bo...
# 20  I prefer knowing the prediction accuracy on bo...
# 21  I prefer knowing the prediction accuracy on bo...
# 22  I prefer knowing the prediction accuracy on bo...
# 23  I prefer knowing the prediction accuracy on bo...
# 24  I prefer knowing the prediction accuracy on bo...
# 25  I prefer knowing only the prediction accuracy ...
# 26  I prefer knowing only the prediction accuracy ...
# 27                                      No preference
# 28  I prefer knowing the prediction accuracy on bo...
# 29  I prefer knowing the prediction accuracy on bo...
# 30  I prefer knowing the prediction accuracy on bo...
# 31  I prefer knowing the prediction accuracy on bo...
# 32  I prefer knowing the prediction accuracy on bo...
# 33  I prefer knowing the prediction accuracy on bo...
# 34  I prefer knowing the prediction accuracy on bo...
# 35  I prefer knowing the prediction accuracy on bo...
# 36  I prefer knowing the prediction accuracy on bo...
# 37  I prefer knowing the prediction accuracy on bo...
# 38  I prefer knowing the prediction accuracy on bo...
# 39  I prefer knowing only the prediction accuracy ...
# 40  I prefer knowing only the prediction accuracy ...
# 41  I prefer knowing the prediction accuracy on bo...
# 42  I prefer knowing the prediction accuracy on bo...
# 43  I prefer knowing the prediction accuracy on bo...
# 44  I prefer knowing only the prediction accuracy ...
# 45  I prefer knowing the prediction accuracy on bo...
# 46  I prefer knowing only the prediction accuracy ...
# 47  I prefer knowing the prediction accuracy on bo...
# 48  I prefer knowing the prediction accuracy on bo...
# 49  I prefer knowing the prediction accuracy on bo...
# 50  I prefer knowing the prediction accuracy on bo...
# 51  I prefer knowing the prediction accuracy on bo...
# 52                                      No preference
# 53  I prefer knowing the prediction accuracy on bo...
# 54  I prefer knowing the prediction accuracy on bo...
# 55  I prefer knowing only the prediction accuracy ...
#
#                                                    q4  \
# 0                        I prefer having both results
# 1                        I prefer having both results
# 2   I prefer having only the result on the noisy data
# 3                        I prefer having both results
# 4   I prefer having only the result on the noisy data
# 5   I prefer having only the result on the noisy data
# 6                                       No preference
# 7                        I prefer having both results
# 8   I prefer having only the result on the noisy data
# 9                        I prefer having both results
# 10                       I prefer having both results
# 11                       I prefer having both results
# 12                       I prefer having both results
# 13  I prefer having only the result on the noisy data
# 14                       I prefer having both results
# 15                       I prefer having both results
# 16                       I prefer having both results
# 17  I prefer having only the result on the noisy data
# 18                       I prefer having both results
# 19                       I prefer having both results
# 20                       I prefer having both results
# 21                       I prefer having both results
# 22                       I prefer having both results
# 23                       I prefer having both results
# 24                       I prefer having both results
# 25  I prefer having only the result on the noisy data
# 26                       I prefer having both results
# 27                       I prefer having both results
# 28  I prefer having only the result on the noisy data
# 29                       I prefer having both results
# 30                       I prefer having both results
# 31  I prefer having only the result on the noisy data
# 32                       I prefer having both results
# 33  I prefer having only the result on the noisy data
# 34                       I prefer having both results
# 35                       I prefer having both results
# 36                                      No preference
# 37  I prefer having only the result on the noisy data
# 38                       I prefer having both results
# 39                       I prefer having both results
# 40                       I prefer having both results
# 41  I prefer having only the result on the noisy data
# 42                       I prefer having both results
# 43                       I prefer having both results
# 44  I prefer having only the result on the noisy data
# 45                       I prefer having both results
# 46  I prefer having only the result on the noisy data
# 47                       I prefer having both results
# 48  I prefer having only the result on the noisy data
# 49  I prefer having only the result on the noisy data
# 50                       I prefer having both results
# 51                       I prefer having both results
# 52                       I prefer having both results
# 53                       I prefer having both results
# 54                       I prefer having both results
# 55                       I prefer having both results
#
#                                             initial_q
# 0   I know about differential privacy but I've nev...
# 1   I know about differential privacy but I've nev...
# 2   I know about differential privacy and I've use...
# 3   I know about differential privacy but I've nev...
# 4   I know about differential privacy but I've nev...
# 5    I don't know anything about differential privacy
# 6    I don't know anything about differential privacy
# 7    I don't know anything about differential privacy
# 8    I don't know anything about differential privacy
# 9   I know about differential privacy but I've nev...
# 10  I know about differential privacy but I've nev...
# 11   I don't know anything about differential privacy
# 12  I know about differential privacy and I've use...
# 13  I know about differential privacy but I've nev...
# 14   I don't know anything about differential privacy
# 15   I don't know anything about differential privacy
# 16  I know about differential privacy but I've nev...
# 17  I know about differential privacy but I've nev...
# 18   I don't know anything about differential privacy
# 19  I know about differential privacy but I've nev...
# 20   I don't know anything about differential privacy
# 21  I know about differential privacy but I've nev...
# 22   I don't know anything about differential privacy
# 23  I know about differential privacy but I've nev...
# 24  I know about differential privacy and I've use...
# 25  I know about differential privacy but I've nev...
# 26  I know about differential privacy but I've nev...
# 27  I know about differential privacy and I've use...
# 28  I know about differential privacy but I've nev...
# 29  I know about differential privacy but I've nev...
# 30  I know about differential privacy but I've nev...
# 31   I don't know anything about differential privacy
# 32  I know about differential privacy but I've nev...
# 33   I don't know anything about differential privacy
# 34  I know about differential privacy but I've nev...
# 35  I am an expert in differential privacy and I'v...
# 36   I don't know anything about differential privacy
# 37   I don't know anything about differential privacy
# 38   I don't know anything about differential privacy
# 39   I don't know anything about differential privacy
# 40   I don't know anything about differential privacy
# 41  I know about differential privacy but I've nev...
# 42   I don't know anything about differential privacy
# 43   I don't know anything about differential privacy
# 44   I don't know anything about differential privacy
# 45   I don't know anything about differential privacy
# 46   I don't know anything about differential privacy
# 47   I don't know anything about differential privacy
# 48   I don't know anything about differential privacy
# 49   I don't know anything about differential privacy
# 50  I know about differential privacy but I've nev...
# 51   I don't know anything about differential privacy
# 52   I don't know anything about differential privacy
# 53  I know about differential privacy but I've nev...
# 54  I know about differential privacy but I've nev...
# 55  I know about differential privacy but I've nev...

# %%
data = []
control1 = df["control1"].dropna()
control2 = df["control2"].dropna()
test1 = df["test1"].dropna()
test2 = df["test2"].dropna()

for eps1, eps2 in zip(control1, control2):
    data.append(["Control", eps1, eps2])

for eps1, eps2 in zip(test1, test2):
    data.append(["Treatment", eps1, eps2])

df1 = pd.DataFrame(data=data, columns=["group", "Q1", "Q2"])
df1
# Out:
#         group   Q1   Q2
# 0     Control  2.5  3.0
# 1     Control  1.0  1.5
# 2     Control  3.5  3.5
# 3     Control  3.5  3.5
# 4     Control  3.5  3.5
# 5     Control  2.0  3.0
# 6     Control  1.5  2.0
# 7     Control  4.0  4.0
# 8     Control  2.0  1.5
# 9     Control  4.0  3.5
# 10    Control  2.0  3.0
# 11    Control  2.0  4.0
# 12    Control  2.5  1.5
# 13    Control  0.5  0.5
# 14    Control  4.5  4.0
# 15    Control  2.0  4.5
# 16    Control  4.5  4.0
# 17    Control  3.0  3.5
# 18    Control  3.5  4.0
# 19    Control  4.0  5.0
# 20    Control  1.5  2.5
# 21    Control  3.0  2.5
# 22    Control  2.0  4.0
# 23    Control  3.5  5.0
# 24    Control  2.0  2.0
# 25    Control  2.5  5.0
# 26    Control  2.5  4.0
# 27    Control  2.0  4.5
# 28    Control  3.5  3.5
# 29  Treatment  1.0  1.0
# 30  Treatment  1.5  2.0
# 31  Treatment  1.5  2.0
# 32  Treatment  1.0  1.5
# 33  Treatment  2.0  2.0
# 34  Treatment  2.5  2.5
# 35  Treatment  1.5  2.0
# 36  Treatment  2.0  1.5
# 37  Treatment  2.0  1.5
# 38  Treatment  1.5  2.0
# 39  Treatment  2.0  1.5
# 40  Treatment  1.5  2.0
# 41  Treatment  3.0  2.0
# 42  Treatment  2.0  1.5
# 43  Treatment  2.5  3.0
# 44  Treatment  1.5  2.0
# 45  Treatment  2.0  2.0
# 46  Treatment  2.5  3.0
# 47  Treatment  1.5  2.0
# 48  Treatment  1.5  4.0
# 49  Treatment  2.0  1.5
# 50  Treatment  2.0  2.0
# 51  Treatment  2.0  3.0
# 52  Treatment  3.5  3.5
# 53  Treatment  3.5  3.0
# 54  Treatment  2.0  2.0
# 55  Treatment  2.0  2.0

# %%
from scipy import stats

stats.mannwhitneyu(control1, test1)
# Out:
# MannwhitneyuResult(statistic=567.0, pvalue=0.003242008929831257)

# %%
stats.mannwhitneyu(control2, test2)
# Out:
# MannwhitneyuResult(statistic=622.5, pvalue=0.00012400701676339659)

# %%
df1 = df1.melt(id_vars="group", var_name="query", value_name="epsilon")
df1
# Out:
#          group query  epsilon
# 0      Control    Q1      2.5
# 1      Control    Q1      1.0
# 2      Control    Q1      3.5
# 3      Control    Q1      3.5
# 4      Control    Q1      3.5
# ..         ...   ...      ...
# 107  Treatment    Q2      3.0
# 108  Treatment    Q2      3.5
# 109  Treatment    Q2      3.0
# 110  Treatment    Q2      2.0
# 111  Treatment    Q2      2.0
#
# [112 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300
sns.set_theme(style="ticks", palette="colorblind", font="Times New Roman", font_scale=1.6)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
fig_width, fig_height = plt.gcf().get_size_inches()

# %%
g = sns.swarmplot(data=df1, x="query", y="epsilon", hue="group", dodge=True, size=7)
_ = g.set(xlabel=None, ylabel="Epsilon")
_ = g.set_yticks([i for i in np.arange(0.5, 5.1, 0.5)])
plt.legend(fontsize='x-small', title_fontsize='x-small', loc='upper right')
g.legend_.set_title(None)
plt.tight_layout()
plt.savefig("figures/swarmplot.pdf")
plt.show()
plt.close()

# %%
df2 = df[df["initial_q"] == "I don't know anything about differential privacy"]
df2
# Out:
#     control1  control2  test1  test2 test_follow_up  \
# 5        NaN       NaN    1.5    2.0            Yes
# 6        3.5       3.5    NaN    NaN            NaN
# 7        3.5       3.5    NaN    NaN            NaN
# 8        NaN       NaN    1.0    1.5            Yes
# 11       1.5       2.0    NaN    NaN            NaN
# 14       NaN       NaN    1.5    2.0            Yes
# 15       NaN       NaN    2.0    1.5            Yes
# 18       2.0       3.0    NaN    NaN            NaN
# 20       NaN       NaN    2.0    1.5            Yes
# 22       NaN       NaN    1.5    2.0            Yes
# 31       2.0       4.5    NaN    NaN            NaN
# 33       3.0       3.5    NaN    NaN            NaN
# 36       NaN       NaN    2.5    3.0            Yes
# 37       NaN       NaN    1.5    2.0            Yes
# 38       4.0       5.0    NaN    NaN            NaN
# 39       NaN       NaN    1.5    4.0            Yes
# 40       1.5       2.5    NaN    NaN            NaN
# 42       NaN       NaN    2.0    1.5            Yes
# 43       2.0       4.0    NaN    NaN            NaN
# 44       3.5       5.0    NaN    NaN            NaN
# 45       NaN       NaN    2.0    2.0            Yes
# 46       2.0       2.0    NaN    NaN            NaN
# 47       NaN       NaN    2.0    3.0            Yes
# 48       NaN       NaN    3.5    3.5            Yes
# 49       2.5       5.0    NaN    NaN            NaN
# 51       NaN       NaN    3.5    3.0            Yes
# 52       2.0       4.5    NaN    NaN            NaN
#
#                                                    q3  \
# 5   I prefer knowing only the prediction accuracy ...
# 6   I prefer knowing the prediction accuracy on bo...
# 7   I prefer knowing the prediction accuracy on bo...
# 8   I prefer knowing the prediction accuracy on bo...
# 11  I prefer knowing only the prediction accuracy ...
# 14  I prefer knowing the prediction accuracy on bo...
# 15  I prefer knowing the prediction accuracy on bo...
# 18  I prefer knowing the prediction accuracy on bo...
# 20  I prefer knowing the prediction accuracy on bo...
# 22  I prefer knowing the prediction accuracy on bo...
# 31  I prefer knowing the prediction accuracy on bo...
# 33  I prefer knowing the prediction accuracy on bo...
# 36  I prefer knowing the prediction accuracy on bo...
# 37  I prefer knowing the prediction accuracy on bo...
# 38  I prefer knowing the prediction accuracy on bo...
# 39  I prefer knowing only the prediction accuracy ...
# 40  I prefer knowing only the prediction accuracy ...
# 42  I prefer knowing the prediction accuracy on bo...
# 43  I prefer knowing the prediction accuracy on bo...
# 44  I prefer knowing only the prediction accuracy ...
# 45  I prefer knowing the prediction accuracy on bo...
# 46  I prefer knowing only the prediction accuracy ...
# 47  I prefer knowing the prediction accuracy on bo...
# 48  I prefer knowing the prediction accuracy on bo...
# 49  I prefer knowing the prediction accuracy on bo...
# 51  I prefer knowing the prediction accuracy on bo...
# 52                                      No preference
#
#                                                    q4  \
# 5   I prefer having only the result on the noisy data
# 6                                       No preference
# 7                        I prefer having both results
# 8   I prefer having only the result on the noisy data
# 11                       I prefer having both results
# 14                       I prefer having both results
# 15                       I prefer having both results
# 18                       I prefer having both results
# 20                       I prefer having both results
# 22                       I prefer having both results
# 31  I prefer having only the result on the noisy data
# 33  I prefer having only the result on the noisy data
# 36                                      No preference
# 37  I prefer having only the result on the noisy data
# 38                       I prefer having both results
# 39                       I prefer having both results
# 40                       I prefer having both results
# 42                       I prefer having both results
# 43                       I prefer having both results
# 44  I prefer having only the result on the noisy data
# 45                       I prefer having both results
# 46  I prefer having only the result on the noisy data
# 47                       I prefer having both results
# 48  I prefer having only the result on the noisy data
# 49  I prefer having only the result on the noisy data
# 51                       I prefer having both results
# 52                       I prefer having both results
#
#                                            initial_q
# 5   I don't know anything about differential privacy
# 6   I don't know anything about differential privacy
# 7   I don't know anything about differential privacy
# 8   I don't know anything about differential privacy
# 11  I don't know anything about differential privacy
# 14  I don't know anything about differential privacy
# 15  I don't know anything about differential privacy
# 18  I don't know anything about differential privacy
# 20  I don't know anything about differential privacy
# 22  I don't know anything about differential privacy
# 31  I don't know anything about differential privacy
# 33  I don't know anything about differential privacy
# 36  I don't know anything about differential privacy
# 37  I don't know anything about differential privacy
# 38  I don't know anything about differential privacy
# 39  I don't know anything about differential privacy
# 40  I don't know anything about differential privacy
# 42  I don't know anything about differential privacy
# 43  I don't know anything about differential privacy
# 44  I don't know anything about differential privacy
# 45  I don't know anything about differential privacy
# 46  I don't know anything about differential privacy
# 47  I don't know anything about differential privacy
# 48  I don't know anything about differential privacy
# 49  I don't know anything about differential privacy
# 51  I don't know anything about differential privacy
# 52  I don't know anything about differential privacy

# %%
data = []

df2 = df[df["initial_q"] == "I don't know anything about differential privacy"]
control1 = df2["control1"].dropna()
control2 = df2["control2"].dropna()
test1 = df2["test1"].dropna()
test2 = df2["test2"].dropna()

for eps1, eps2 in zip(control1, control2):
    data.append(["Does not know DP", "Control", eps1, eps2])
for eps1, eps2 in zip(test1, test2):
    data.append(["Does not know DP", "Treatment", eps1, eps2])

df2 = df[df["initial_q"] != "I don't know anything about differential privacy"]
control1 = df2["control1"].dropna()
control2 = df2["control2"].dropna()
test1 = df2["test1"].dropna()
test2 = df2["test2"].dropna()

for eps1, eps2 in zip(control1, control2):
    data.append(["Knows DP", "Control", eps1, eps2])
for eps1, eps2 in zip(test1, test2):
    data.append(["Knows DP", "Treatment", eps1, eps2])

df2 = pd.DataFrame(data=data, columns=["know_dp", "group", "Q1", "Q2"])
df2
# Out:
#              know_dp      group   Q1   Q2
# 0   Does not know DP    Control  3.5  3.5
# 1   Does not know DP    Control  3.5  3.5
# 2   Does not know DP    Control  1.5  2.0
# 3   Does not know DP    Control  2.0  3.0
# 4   Does not know DP    Control  2.0  4.5
# 5   Does not know DP    Control  3.0  3.5
# 6   Does not know DP    Control  4.0  5.0
# 7   Does not know DP    Control  1.5  2.5
# 8   Does not know DP    Control  2.0  4.0
# 9   Does not know DP    Control  3.5  5.0
# 10  Does not know DP    Control  2.0  2.0
# 11  Does not know DP    Control  2.5  5.0
# 12  Does not know DP    Control  2.0  4.5
# 13  Does not know DP  Treatment  1.5  2.0
# 14  Does not know DP  Treatment  1.0  1.5
# 15  Does not know DP  Treatment  1.5  2.0
# 16  Does not know DP  Treatment  2.0  1.5
# 17  Does not know DP  Treatment  2.0  1.5
# 18  Does not know DP  Treatment  1.5  2.0
# 19  Does not know DP  Treatment  2.5  3.0
# 20  Does not know DP  Treatment  1.5  2.0
# 21  Does not know DP  Treatment  1.5  4.0
# 22  Does not know DP  Treatment  2.0  1.5
# 23  Does not know DP  Treatment  2.0  2.0
# 24  Does not know DP  Treatment  2.0  3.0
# 25  Does not know DP  Treatment  3.5  3.5
# 26  Does not know DP  Treatment  3.5  3.0
# 27          Knows DP    Control  2.5  3.0
# 28          Knows DP    Control  1.0  1.5
# 29          Knows DP    Control  3.5  3.5
# 30          Knows DP    Control  2.0  3.0
# 31          Knows DP    Control  4.0  4.0
# 32          Knows DP    Control  2.0  1.5
# 33          Knows DP    Control  4.0  3.5
# 34          Knows DP    Control  2.0  4.0
# 35          Knows DP    Control  2.5  1.5
# 36          Knows DP    Control  0.5  0.5
# 37          Knows DP    Control  4.5  4.0
# 38          Knows DP    Control  4.5  4.0
# 39          Knows DP    Control  3.5  4.0
# 40          Knows DP    Control  3.0  2.5
# 41          Knows DP    Control  2.5  4.0
# 42          Knows DP    Control  3.5  3.5
# 43          Knows DP  Treatment  1.0  1.0
# 44          Knows DP  Treatment  1.5  2.0
# 45          Knows DP  Treatment  2.0  2.0
# 46          Knows DP  Treatment  2.5  2.5
# 47          Knows DP  Treatment  2.0  1.5
# 48          Knows DP  Treatment  1.5  2.0
# 49          Knows DP  Treatment  3.0  2.0
# 50          Knows DP  Treatment  2.0  1.5
# 51          Knows DP  Treatment  2.5  3.0
# 52          Knows DP  Treatment  1.5  2.0
# 53          Knows DP  Treatment  2.0  2.0
# 54          Knows DP  Treatment  2.0  2.0
# 55          Knows DP  Treatment  2.0  2.0

# %%
df2 = df2.melt(id_vars=["know_dp", "group"], var_name="query", value_name="epsilon")
df2
# Out:
#               know_dp      group query  epsilon
# 0    Does not know DP    Control    Q1      3.5
# 1    Does not know DP    Control    Q1      3.5
# 2    Does not know DP    Control    Q1      1.5
# 3    Does not know DP    Control    Q1      2.0
# 4    Does not know DP    Control    Q1      2.0
# ..                ...        ...   ...      ...
# 107          Knows DP  Treatment    Q2      3.0
# 108          Knows DP  Treatment    Q2      2.0
# 109          Knows DP  Treatment    Q2      2.0
# 110          Knows DP  Treatment    Q2      2.0
# 111          Knows DP  Treatment    Q2      2.0
#
# [112 rows x 4 columns]

# %%
# fig_width, fig_height = plt.gcf().get_size_inches()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(fig_width * 1.5, fig_height), sharey=True)

g = sns.swarmplot(data=df2[df2["know_dp"] == "Does not know DP"], x="query", y="epsilon", hue="group", dodge=True, size=7, ax=ax1)
_ = g.set(xlabel="Does not know DP", ylabel="Epsilon")
_ = g.set_yticks([i for i in np.arange(0.5, 5.1, 0.5)])
ax1.legend(fontsize='small')
g.legend_.set_title(None)

g = sns.swarmplot(data=df2[df2["know_dp"] == "Knows DP"], x="query", y="epsilon", hue="group", dodge=True, size=7, ax=ax2)
_ = g.set(xlabel="Knows DP", ylabel="Epsilon")
_ = g.set_yticks([i for i in np.arange(0.5, 5.1, 0.5)])
ax2.legend(fontsize='small')
g.legend_.set_title(None)

ax1.label_outer()
ax2.label_outer()


plt.tight_layout()
plt.savefig("figures/swarmplot_stratify.pdf")
plt.show()
plt.close()

# %%
df["q3"].value_counts()
# Out:
# I prefer knowing the prediction accuracy on both noisy data and original data    42
# I prefer knowing only the prediction accuracy on the noisy data                  12
# No preference                                                                     2
# Name: q3, dtype: int64

# %%
df[df["initial_q"] == "I don't know anything about differential privacy"]["q3"].value_counts()
# Out:
# I prefer knowing the prediction accuracy on both noisy data and original data    20
# I prefer knowing only the prediction accuracy on the noisy data                   6
# No preference                                                                     1
# Name: q3, dtype: int64

# %%
df[df["initial_q"] != "I don't know anything about differential privacy"]["q3"].value_counts()
# Out:
# I prefer knowing the prediction accuracy on both noisy data and original data    22
# I prefer knowing only the prediction accuracy on the noisy data                   6
# No preference                                                                     1
# Name: q3, dtype: int64

# %%
df["q4"].value_counts()
# Out:
# I prefer having both results                         38
# I prefer having only the result on the noisy data    16
# No preference                                         2
# Name: q4, dtype: int64

# %%
df[df["initial_q"] == "I don't know anything about differential privacy"]["q4"].value_counts()
# Out:
# I prefer having both results                         16
# I prefer having only the result on the noisy data     9
# No preference                                         2
# Name: q4, dtype: int64

# %%
df[df["initial_q"] != "I don't know anything about differential privacy"]["q4"].value_counts()
# Out:
# I prefer having both results                         22
# I prefer having only the result on the noisy data     7
# Name: q4, dtype: int64

# %%
df["test_follow_up"].value_counts()
# Out:
# Yes    27
# Name: test_follow_up, dtype: int64

# %%
df["initial_q"].value_counts()
# Out:
# I don't know anything about differential privacy                                                                               27
# I know about differential privacy but I've never used it in practice                                                           24
# I know about differential privacy and I've used it in practice                                                                  4
# I am an expert in differential privacy and I've done research / deployed real-world applications about differential privacy     1
# Name: initial_q, dtype: int64

# %%
df_old = pd.read_csv("DP_study_result_nov_17.csv")
df_old.columns = ["control1", "control2", "test1", "test2", "q3", "q4", "duration", "test_follow_up", "initial_q"]
df_old
# Out:
#     control1  control2  test1  test2  \
# 0        3.0       4.0    NaN    NaN
# 1        NaN       NaN    2.0    1.5
# 2        1.5       1.0    NaN    NaN
# 3        2.0       4.0    NaN    NaN
# 4        2.0       4.0    NaN    NaN
# 5        2.5       4.0    NaN    NaN
# 6        NaN       NaN    2.0    2.5
# 7        3.5       3.5    NaN    NaN
# 8        2.5       3.5    NaN    NaN
# 9        2.5       2.0    NaN    NaN
# 10       NaN       NaN    3.5    4.5
# 11       NaN       NaN    2.0    3.5
# 12       2.5       1.5    NaN    NaN
# 13       NaN       NaN    4.0    3.5
# 14       1.5       2.0    NaN    NaN
# 15       NaN       NaN    2.0    2.0
# 16       NaN       NaN    2.0    3.5
# 17       NaN       NaN    3.0    4.0
# 18       NaN       NaN    0.5    2.0
# 19       NaN       NaN    1.5    2.5
# 20       3.5       2.5    NaN    NaN
# 21       3.5       4.0    NaN    NaN
# 22       NaN       NaN    1.5    2.0
# 23       1.0       1.5    NaN    NaN
# 24       NaN       NaN    2.5    3.5
# 25       3.0       3.5    NaN    NaN
# 26       2.0       1.5    NaN    NaN
# 27       NaN       NaN    2.0    2.5
# 28       NaN       NaN    2.0    2.0
# 29       3.5       3.5    NaN    NaN
# 30       NaN       NaN    1.5    2.0
# 31       3.0       4.0    NaN    NaN
# 32       NaN       NaN    3.5    2.5
# 33       4.0       4.0    NaN    NaN
# 34       NaN       NaN    2.0    2.5
# 35       2.0       3.5    NaN    NaN
# 36       NaN       NaN    1.5    4.0
# 37       2.5       4.0    NaN    NaN
# 38       NaN       NaN    1.0    3.5
# 39       NaN       NaN    3.0    2.5
#
#                                                    q3  \
# 0                                       No preference
# 1   I prefer knowing the prediction accuracy on bo...
# 2   I prefer knowing the prediction accuracy on bo...
# 3   I prefer knowing only the prediction accuracy ...
# 4   I prefer knowing the prediction accuracy on bo...
# 5   I prefer knowing the prediction accuracy on bo...
# 6   I prefer knowing the prediction accuracy on bo...
# 7   I prefer knowing the prediction accuracy on bo...
# 8   I prefer knowing the prediction accuracy on bo...
# 9   I prefer knowing the prediction accuracy on bo...
# 10  I prefer knowing only the prediction accuracy ...
# 11  I prefer knowing only the prediction accuracy ...
# 12  I prefer knowing the prediction accuracy on bo...
# 13  I prefer knowing the prediction accuracy on bo...
# 14  I prefer knowing only the prediction accuracy ...
# 15  I prefer knowing the prediction accuracy on bo...
# 16  I prefer knowing the prediction accuracy on bo...
# 17  I prefer knowing the prediction accuracy on bo...
# 18  I prefer knowing the prediction accuracy on bo...
# 19  I prefer knowing only the prediction accuracy ...
# 20  I prefer knowing the prediction accuracy on bo...
# 21  I prefer knowing the prediction accuracy on bo...
# 22  I prefer knowing the prediction accuracy on bo...
# 23  I prefer knowing the prediction accuracy on bo...
# 24  I prefer knowing the prediction accuracy on bo...
# 25  I prefer knowing the prediction accuracy on bo...
# 26  I prefer knowing the prediction accuracy on bo...
# 27  I prefer knowing the prediction accuracy on bo...
# 28  I prefer knowing only the prediction accuracy ...
# 29  I prefer knowing the prediction accuracy on bo...
# 30  I prefer knowing only the prediction accuracy ...
# 31  I prefer knowing the prediction accuracy on bo...
# 32  I prefer knowing the prediction accuracy on bo...
# 33  I prefer knowing the prediction accuracy on bo...
# 34  I prefer knowing only the prediction accuracy ...
# 35  I prefer knowing the prediction accuracy on bo...
# 36  I prefer knowing only the prediction accuracy ...
# 37  I prefer knowing the prediction accuracy on bo...
# 38  I prefer knowing the prediction accuracy on bo...
# 39  I prefer knowing the prediction accuracy on bo...
#
#                                                    q4  duration  \
# 0                        I prefer having both results       451
# 1                        I prefer having both results       762
# 2                        I prefer having both results       731
# 3                        I prefer having both results       813
# 4                        I prefer having both results       866
# 5   I prefer having only the result on the noisy data       402
# 6   I prefer having only the result on the noisy data       608
# 7   I prefer having only the result on the noisy data       972
# 8                        I prefer having both results       436
# 9   I prefer having only the result on the noisy data       636
# 10                       I prefer having both results       689
# 11  I prefer having only the result on the noisy data       625
# 12                       I prefer having both results       397
# 13  I prefer having only the result on the noisy data       778
# 14                       I prefer having both results       580
# 15                       I prefer having both results      1699
# 16                       I prefer having both results       357
# 17                       I prefer having both results       901
# 18                       I prefer having both results      1857
# 19                       I prefer having both results       699
# 20                       I prefer having both results       748
# 21                       I prefer having both results       517
# 22  I prefer having only the result on the noisy data      1727
# 23                       I prefer having both results       505
# 24                       I prefer having both results       423
# 25  I prefer having only the result on the noisy data      1550
# 26                       I prefer having both results      1058
# 27                       I prefer having both results      1003
# 28                       I prefer having both results       807
# 29  I prefer having only the result on the noisy data       558
# 30  I prefer having only the result on the noisy data       503
# 31                       I prefer having both results       549
# 32                       I prefer having both results      1587
# 33                       I prefer having both results       459
# 34  I prefer having only the result on the noisy data       571
# 35                       I prefer having both results       590
# 36                       I prefer having both results      1002
# 37  I prefer having only the result on the noisy data       862
# 38                       I prefer having both results       408
# 39                       I prefer having both results       163
#
#    test_follow_up                                          initial_q
# 0             NaN   I don't know anything about differential privacy
# 1             Yes  I know about differential privacy but I've nev...
# 2             NaN  I know about differential privacy but I've nev...
# 3             NaN   I don't know anything about differential privacy
# 4             NaN   I don't know anything about differential privacy
# 5             NaN   I don't know anything about differential privacy
# 6             Yes   I don't know anything about differential privacy
# 7             NaN  I know about differential privacy but I've nev...
# 8             NaN   I don't know anything about differential privacy
# 9             NaN   I don't know anything about differential privacy
# 10            Yes  I know about differential privacy but I've nev...
# 11            Yes   I don't know anything about differential privacy
# 12            NaN  I know about differential privacy but I've nev...
# 13            Yes   I don't know anything about differential privacy
# 14            NaN   I don't know anything about differential privacy
# 15            Yes   I don't know anything about differential privacy
# 16            Yes   I don't know anything about differential privacy
# 17            Yes   I don't know anything about differential privacy
# 18            Yes   I don't know anything about differential privacy
# 19            Yes   I don't know anything about differential privacy
# 20            NaN   I don't know anything about differential privacy
# 21            NaN  I know about differential privacy but I've nev...
# 22            Yes  I know about differential privacy but I've nev...
# 23            NaN  I know about differential privacy but I've nev...
# 24            Yes  I know about differential privacy but I've nev...
# 25            NaN  I know about differential privacy and I've use...
# 26            NaN   I don't know anything about differential privacy
# 27            Yes  I know about differential privacy but I've nev...
# 28            Yes  I know about differential privacy and I've use...
# 29            NaN   I don't know anything about differential privacy
# 30            Yes  I know about differential privacy but I've nev...
# 31            NaN   I don't know anything about differential privacy
# 32            Yes  I know about differential privacy and I've use...
# 33            NaN  I know about differential privacy and I've use...
# 34            Yes   I don't know anything about differential privacy
# 35            NaN  I know about differential privacy but I've nev...
# 36            Yes   I don't know anything about differential privacy
# 37            NaN   I don't know anything about differential privacy
# 38            Yes   I don't know anything about differential privacy
# 39            Yes  I know about differential privacy but I've nev...

# %%
data = []
histogram1 = df_old["test1"].dropna()
histogram2 = df_old["test2"].dropna()
range1 = df["test1"].dropna()
range2 = df["test2"].dropna()

for eps1, eps2 in zip(histogram1, histogram2):
    data.append(["Histogram", eps1, eps2])

for eps1, eps2 in zip(range1, range2):
    data.append(["Range", eps1, eps2])

df3 = pd.DataFrame(data=data, columns=["group", "Q1", "Q2"])
df3
# Out:
#         group   Q1   Q2
# 0   Histogram  2.0  1.5
# 1   Histogram  2.0  2.5
# 2   Histogram  3.5  4.5
# 3   Histogram  2.0  3.5
# 4   Histogram  4.0  3.5
# 5   Histogram  2.0  2.0
# 6   Histogram  2.0  3.5
# 7   Histogram  3.0  4.0
# 8   Histogram  0.5  2.0
# 9   Histogram  1.5  2.5
# 10  Histogram  1.5  2.0
# 11  Histogram  2.5  3.5
# 12  Histogram  2.0  2.5
# 13  Histogram  2.0  2.0
# 14  Histogram  1.5  2.0
# 15  Histogram  3.5  2.5
# 16  Histogram  2.0  2.5
# 17  Histogram  1.5  4.0
# 18  Histogram  1.0  3.5
# 19  Histogram  3.0  2.5
# 20      Range  1.0  1.0
# 21      Range  1.5  2.0
# 22      Range  1.5  2.0
# 23      Range  1.0  1.5
# 24      Range  2.0  2.0
# 25      Range  2.5  2.5
# 26      Range  1.5  2.0
# 27      Range  2.0  1.5
# 28      Range  2.0  1.5
# 29      Range  1.5  2.0
# 30      Range  2.0  1.5
# 31      Range  1.5  2.0
# 32      Range  3.0  2.0
# 33      Range  2.0  1.5
# 34      Range  2.5  3.0
# 35      Range  1.5  2.0
# 36      Range  2.0  2.0
# 37      Range  2.5  3.0
# 38      Range  1.5  2.0
# 39      Range  1.5  4.0
# 40      Range  2.0  1.5
# 41      Range  2.0  2.0
# 42      Range  2.0  3.0
# 43      Range  3.5  3.5
# 44      Range  3.5  3.0
# 45      Range  2.0  2.0
# 46      Range  2.0  2.0

# %%
df3 = df3.melt(id_vars="group", var_name="query", value_name="epsilon")
df3
# Out:
#         group query  epsilon
# 0   Histogram    Q1      2.0
# 1   Histogram    Q1      2.0
# 2   Histogram    Q1      3.5
# 3   Histogram    Q1      2.0
# 4   Histogram    Q1      4.0
# ..        ...   ...      ...
# 89      Range    Q2      3.0
# 90      Range    Q2      3.5
# 91      Range    Q2      3.0
# 92      Range    Q2      2.0
# 93      Range    Q2      2.0
#
# [94 rows x 3 columns]

# %%
g = sns.swarmplot(data=df3, x="query", y="epsilon", hue="group", dodge=True, size=7)
_ = g.set(xlabel=None, ylabel="Epsilon")
_ = g.set_yticks([i for i in np.arange(0.5, 5.1, 0.5)])
plt.legend(fontsize='x-small', title_fontsize='x-small')
g.legend_.set_title(None)
plt.tight_layout()
plt.savefig("figures/swarmplot_hist_range.pdf")
plt.show()
plt.close()
